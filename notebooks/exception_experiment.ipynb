# %%
import sys
import traceback
from logger.custom_logger import CustomLogger
logger=CustomLogger().get_logger("exception_experiment")
logger
# Out:
# <Logger exception_experiment (INFO)>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class CustomDocumentException(Exception):
    """Custom Exception for Document Portal"""
    def __init__(self, error_message: str, error_details: sys):
        _,_,exe_tb = error_details.exc_info() 
        
        self.file_name = exe_tb.tb_frame.f_code.co_filename
        self.lineno = exe_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))
        
    
    def __str__(self):
        return f"""Error occured in [{self.file_name}] at line [{self.lineno}]
            Message: {self.error_message}
            Traceback: {self.traceback_str}"""
    
if __name__ == "__main__":
    try:
        a = 1 / 0
        print(a)
    except Exception as e:
        app_exec = CustomDocumentException(e, sys)
        logger.error(app_exec)
        raise app_exec
# Out:
# 2025-07-26 16:29:47 [error    ] Error occured in [C:\Users\Suel.Abbasi\AppData\Local\Temp\ipykernel_41964\540078382.py] at line [19]
#             Message: division by zero
#             Traceback: Traceback (most recent call last):
#   File "C:\Users\Suel.Abbasi\AppData\Local\Temp\ipykernel_41964\540078382.py", line 19, in <module>
#     a = 1 / 0
#         ~~^~~
# ZeroDivisionError: division by zero
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[34], line 19
#      18 try:
# ---> 19     a = 1 / 0
#      20     print(a)
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# CustomDocumentException                   Traceback (most recent call last)
# Cell In[34], line 24
#      22 app_exec = CustomDocumentException(e, sys)
#      23 logger.error(app_exec)
# ---> 24 raise app_exec
#
# CustomDocumentException: Error occured in [C:\Users\Suel.Abbasi\AppData\Local\Temp\ipykernel_41964\540078382.py] at line [19]
#             Message: division by zero
#             Traceback: Traceback (most recent call last):
#   File "C:\Users\Suel.Abbasi\AppData\Local\Temp\ipykernel_41964\540078382.py", line 19, in <module>
#     a = 1 / 0
#         ~~^~~
# ZeroDivisionError: division by zero

# %%
"""
1. log this error(file, cloud config, command prompt) (it will keep the record of the error and will not stop the execution of the code)
2. raise the exception(it will stop the execution of the code)
"""
# Out:
# '\n1. log this error(file, cloud config, command prompt) (it will keep the record of the error and will not stop the execution of the code)\n2. raise the exception(it will stop the execution of the code)\n'

# %%
import structlog

# %%
logger = structlog.get_logger()

# %%
logger.info(f'User uploaded a file id {123}, with file name {'report.pdf'} ')
# Out:
# 2025-07-26 16:23:38 [info     ] User uploaded a file id 123, with file name report.pdf
